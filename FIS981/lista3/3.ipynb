# %% [markdown]
# ## Problema 3
#
# As equações de Lorentz (abaixo) são certamente um dos conjuntos de equações mais famosos em Física. Essas equações foram estudadas pela primeira vez por Lorentz em 1963 que as derivou para um modelo simplificado de padrões de clima. Sua fama vem do fato de serem um dos primeiros exemplos de Caos Determinístico.
#
# $$\frac{dx}{dt} = \sigma (y-x)\quad , \quad  \frac{dy}{dt} = rx - y - xz \quad , \quad \frac{dz}{dt} = xy-bz$$
#
# onde $\sigma$, $r$ e $b$ são constantes.
#
# (a) escreva um programa para resolver as equações de Lorentz para o caso $\sigma = 10$, $r = 28$ e $b=8/3$ no intervalo de $t=0$ a $t=50$ e condições iniciais $(x,y,z) = (0,1,0)$.
#
# (b) faça um gráfico de $y$ em função de $t$. O que você observa nesse gráfico?
#
# (c) faça um gráfico de $z$ em função de $x$. Você consegue identificar esse gráfico? Qual propriedade importante ele tem?

# %%
# Importando as bibliotecas necessárias
import numpy as np
import matplotlib.pyplot as plt

# Definição das equações de Lorentz
def lorenz(x, y, z, s=10., r=28., b=2.667):
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return x_dot, y_dot, z_dot

dt = 0.01
cont = 10000

# Adicionando um espaço extra para os valores iniciais
xs = np.empty((cont + 1,))
ys = np.empty((cont + 1,))
zs = np.empty((cont + 1,))

# Valores inciais
xs[0], ys[0], zs[0] = (0., 1., 0.)

# Loop para a evolução temporal
for i in range(cont):
    x_dot, y_dot, z_dot = lorenz(xs[i], ys[i], zs[i])
    xs[i + 1] = xs[i] + (x_dot * dt)
    ys[i + 1] = ys[i] + (y_dot * dt)
    zs[i + 1] = zs[i] + (z_dot * dt)

# Imprimindo os resultados
print("dx/dt: ", x_dot)
print("dy/dt: ", y_dot)
print("dz/dt: ", z_dot)
# Out:
# dx/dt:  -21.4611559525
# dy/dt:  -41.4944845069
# dz/dt:  -14.668485509

# %%
# Montando uma lista do tempo do mesmo tamanho de ys
tempo = np.linspace(0,50,10001)

# Plotando o gráfico Y x T
plt.plot(tempo, ys)
plt.ylabel('Y')
plt.xlabel('t(s)')
plt.title("Y x t")
plt.show()

# %%
# Plotando o gráfico Z x X
plt.plot(xs, zs)
plt.xlabel('X')
plt.ylabel('Z')
plt.title("Z x X")
plt.show()
